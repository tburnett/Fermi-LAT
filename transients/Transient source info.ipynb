# %% [markdown]
# #Transient source information

# %%
# %matplotlib inline
month=2
os.chdir(os.path.expandvars('$FERMI/skymodels/P301_monthly/month%02d'%month))
from uw.like2.analyze import (sourceinfo, transientinfo, localization, associations,)
map(reload, (sourceinfo, transientinfo, localization, associations,));

# %%
self=transientinfo.TransientInfo(refresh=False)
# Out:
# loading sources.pickle
# transients: 606
# loading sources.pickle
# 68 poorly localized (locqual>8.0 or a>0.25 or delta_ts>2.00)
# wrote file "poorly_localized.csv"
# loading sources.pickle
# Associations: set subset, 606 sources, to report on.
# using associations found in sourceinfo
# associated: 42/606

# %%
self.assoc.df['ts acat aname adeltats aprob roiname'.split()]
# Out:
#                      ts        acat             aname   adeltats     aprob    roiname
# name
# TSh02-1212     10.56377       bzcat    5BZQJ0004-4736   0.805295  0.940658  HP12_1665
# TSh02-1228     18.44774      cgrabs        J0026-3512   6.899614  0.966103  HP12_1723
# TSh02-1192     10.95509       bzcat    5BZBJ0038+0013   3.285203  0.893037  HP12_1624
# TSh02-1245     44.67529      cgrabs        J0108+0135   1.136836  0.960030  HP12_1626
# TSh02-1178     11.53648      cgrabs        J0113+0222   4.337170  0.850745  HP12_1626
# TSh02-0942     11.46419  pulsar_big          B0153+39   1.702492  0.941321  HP12_1194
# TSh02-1006     17.92812       bzcat    5BZBJ0203+3042   0.261503  0.964748  HP12_1291
# PGW_02_078_02  26.64467  pulsar_lat    PSR J0248+6021  10.196066  0.989478  HP12_0810
# TSh02-0902     8.102006      cgrabs        J0329+3510   2.031944  0.820228  HP12_1101
# TSh02-1243     28.15708      cgrabs        J0403-3605   3.221648  0.953835  HP12_1534
# TSh02-1025     10.98234  pulsar_big          B0447-12   3.911016  0.801430  HP12_1348
# TSh02-0993     28.67199       bzcat    5BZQJ0559-4529   4.778997  0.932238  HP12_1257
# TSh02-0841     9.376867       bzcat    5BZQJ0606-0724   1.306496  0.905353  HP12_1060
# PGW_02_096_09    25.455  pulsar_lat    PSR J0633+1746   8.348456  0.999953  HP12_0818
# PGW_02_062_11  61.28901       bzcat    5BZQJ0639+7324   1.797537  0.996605  HP12_0523
# TSh02-0422     14.86498         qso       PKS 0805-07   2.755412  0.980203  HP12_0678
# TSh02-0213     7.388811       bzcat    5BZBJ0832+3300   1.670562  0.873608  HP12_0385
# TSh02-0588     16.46321  pulsar_big        J0857-4424   3.370767  0.865709  HP12_0875
# TSh02-0165     14.69511       bzcat    5BZQJ0903+5151   2.503624  0.934646  HP12_0286
# PGW_02_031_06  106.5382      cgrabs        J0923+4125   1.373915  0.994714  HP12_0288
# PGW_02_052_03  10.47685      crates    J100905-230945   0.876387  0.844022  HP12_0490
# PGW_02_100_08  47.49303  pulsar_lat    PSR J1105-6107   9.097822  0.999756  HP12_0878
# TSh02-0104     11.62849       bllac  SDSS J11360+6324   4.612196  0.823693  HP12_0157
# TSh02-0912     36.27233       bzcat    5BZUJ1155-8101   3.991243  0.983917  HP12_1120
# PGW_02_003_05  112.2504       bzcat    5BZQJ1224+2122   0.680567  0.994726  HP12_0009
# TSh02-0158     8.613506      cgrabs        J1243+7442   7.976827  0.860886  HP12_0280
# pars              [4.64970745789e-10, 2.52029235388, 0.0, 262.45...
# pindex                                                     2.520292
# pindex_unc                                                0.1761874
# pivot_energy                                               398.3414
# psr                                                           False
# roiname                                                   HP12_0794
# sedrec            [[100.0, 177.828, 36.6875, 24.4796, 49.1388, 9...
# skydir            (0.0578940510635, -0.974287512746, -0.21774324...
# transient                                                      True
# ts                                                         59.14227
# ts_beta                                                         NaN
# name                                                  PGW_06_073_09
# ra                                                         273.4006
# dec                                                       -12.57652
# hassed                                                         True
# curvature                                              3.996803e-13
# unloc                                                         False
# poorloc                                                       False
# flags                                                             0
# aprob                                                     0.9960337
# acat                                                     pulsar_lat
# aname                                                PSR J1813-1246
# aang                                                      0.2137349
# adeltats                                                   13.39132
# Name: PGW_06_073_09, Length: 57, dtype: object

# %%
self.non_psr_spectral_plots();
# Out:
# 2 sources flagged (1) in tails of flux, index, or beta

# %%
fig=self.assoc.bzcat_study(tsmax=200);
# Out:
# agns: 24
# [10, 13, 1, 0]
# Writing bzcat sumamry

# %%
self.all_plots();
# Out:
# Saving fig cumulative_ts, ... to plots/transients/cumulative_ts_month08.jpg
# 2 sources flagged (1) in tails of flux, index, or beta
# Saving fig non_psr_spectral_plots, ... to plots/transients/non_psr_spectral_plots_month08.jpg
# Not generating plot for log-normal
# 1 sources with bad fits
# 1 sources with missing errors
# fit quality averages: powerlaw: 8.9, logparabola: 0.0, expcutoff(hilat): 0.0, expcutoff(lolat): 0.0
# Saving fig fit_quality, ... to plots/transients/fit_quality_month08.jpg
# Pivot needs fixing: 131 sources
# Saving fig pivot_vs_e0, ... to plots/transients/pivot_vs_e0_month08.jpg
# Saving fig localization, ... to plots/transients/localization_month08.jpg
# Saving fig locqual_hist, ... to plots/transients/locqual_hist_month08.jpg
# agns: 24
# [10, 13, 1, 0]
# Writing bzcat sumamry
# *** docstring processing problem: 'self.bzcat_html'
# Saving fig bzcat_study, ... to plots/transients/bzcat_study_month08.jpg
# **** failed to write footer: 'NoneType' object has no attribute 'group'
# saved local menu to plots/transients/menu.html
# saved html doc to plots/transients/index.html
# wrote menu /nfs/farm/g/glast/g/catalog/pointlike/skymodels/P301_monthly/month08/plots/index.html

# %%
len(self.df)
# Out:
# 596

# %%
test=[-1]* len(dfagn)
bzname=[]; bzts=[]; bzsname=[]
for i,a in enumerate(dfagn.associations):
    prob = a['prob']
    for j,p in enumerate(prob):
        if p>0.8 and a['cat'][j]=='bzcat':
            test[i]=j
            bzname.append(a['name'][j])
            bzts.append(dfagn.ts[i])
            bzsname.append(dfagn.index[i])
            
t=np.asarray(test)
u =[sum(t==k) for k in range(-1,3)] ; print u
print 'There is a BZCAT association in all but %d out of %d agns' % (u[0], sum(u))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-29f099d30a75> in <module>()
# ----> 1 test=[-1]* len(dfagn)
#       2 bzname=[]; bzts=[]; bzsname=[]
#       3 for i,a in enumerate(dfagn.associations):
#       4     prob = a['prob']
#       5     for j,p in enumerate(prob):
#
# NameError: name 'dfagn' is not defined

# %%
self.df.associations.ix[0]
# Out:
# {'ang': [0.074373033280594344, 0.074377563954705489],
#  'cat': ['agn', 'seyfert'],
#  'dec': [-44.65916824340821, -44.6592],
#  'deltats': [0.84658478510027635, 0.84673249554316499],
#  'density': [0.13931715058791933, 0.1592196006719078],
#  'dir': [SkyDir(0.223,-44.659), SkyDir(0.223,-44.659)],
#  'name': ['CTS C16.16', 'CTS C16.16'],
#  'prior': [0.023, 0.0012],
#  'prob': [0.63094299102826412, 0.070927158456515649],
#  'ra': [0.22333332896232605, 0.22330000000000005]}

# %%
self.assoc.df['ts aprob acat aname'.split()]
# Out:
#                      ts     aprob        acat              aname
# name
# TSh08-1214     10.78865  0.827130       bllac   SDSS J00217-0900
# PGW_08_175_04  9.664055  0.997327      cgrabs         J0403-3605
# PGW_08_127_13  12.62555  0.809962      crates     J041719+363136
# TSh08-1018     9.320279  0.959153       bllac       2E 0414+0057
# PGW_08_128_04  26.78242  0.911071       bllac  1WGA J0421.5+1433
# TSh08-1067     10.66158  0.845216       bzcat     5BZQJ0448-3659
# TSh08-1024     19.47145  0.860288       bzcat     5BZQJ0526-4830
# TSh08-0988     10.87503  0.990040  pulsar_lat     PSR J0540-6919
# TSh08-0287     10.46678  0.994204  pulsar_lat     PSR J0533+6759
# PGW_08_031_02   28.4149  0.960858      crates     J085137+484734
# TSh08-0179     7.123807  0.910051  pulsar_big           B0919+06
# TSh08-0280     12.88772  0.995955       bzcat     5BZQJ0932-2016
# TSh08-0139     10.16962  0.973687  starbursts               M 82
# TSh08-0384      11.3423  0.968147      crates     J095830-361230
# PGW_08_029_02  38.24597  0.878929      cgrabs         J1048+7143
# TSh08-0417     15.72503  0.957767      crates     J112846-485018
# PGW_08_007_04  21.99512  0.964618      cgrabs         J1146+3958
# PGW_08_002_04  43.46219  0.989990       bzcat     5BZQJ1224+2122
# TSh08-0024     40.37189  0.865670       bzcat     5BZQJ1239+0443
# TSh08-0061     12.56549  0.862452      crates     J135037+613254
# TSh08-0056     11.40822  0.884953       bzcat     5BZBJ1440+0610
# TSh08-0358       13.585  0.999657  pulsar_lat     PSR J1600-3053
# PGW_08_045_04  12.90461  0.908866       bzcat     5BZUJ1632+8232
# TSh08-0108     133.9034  0.977501      cgrabs         J1635+3808
# TSh08-0926     11.26871  0.967493      crates     J164053-775844
# TSh08-0228     11.03196  0.990565       bzcat     5BZBJ1800+7828
# TSh08-0391     6.901138  0.923098      cgrabs         J1849+3024
# PGW_08_136_07   8.26162  0.980182      cgrabs         J1937-3958
# TSh08-0990     14.08976  0.860806      crates     J195059-732231
# PGW_08_121_02  27.63699  0.826732       bzcat     5BZQJ2000-1748
# TSh08-0511     22.93021  0.835703       bzcat     5BZQJ2007+4029
# PGW_08_109_09  7.974901  0.999895  pulsar_lat     PSR J2238+5903
# PGW_08_155_04  111.4284  0.992559      cgrabs         J2253+1608
# TSh08-1124     13.67395  0.925339       bzcat     5BZQJ2256-6533
# TSh08-1208     9.058399  0.855473      cgrabs         J2314-3138
# TSh08-0879     15.06787  0.811643      crates     J231748+425413
# PGW_08_178_01  129.3151  0.987077       bzcat     5BZQJ2329-4955
# TSh08-1215     28.63227  0.958138       bzcat     5BZQJ2345-1555
