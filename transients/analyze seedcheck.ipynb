# %% [markdown]
# #Analyze seedcheck

# %%
# %matplotlib inline
os.chdir(os.path.expandvars('$FERMI/skymodels/P301_monthly/month10'))
from uw.like2.analyze import (seedcheck,)
map(reload, (seedcheck,))
# Out:
# [<module 'uw.like2.analyze.seedcheck' from '/afs/slac/g/glast/groups/catalog/pointlike/python/uw/like2/analyze/seedcheck.py'>]

# %%
self = seedcheck.SeedCheck()
# Out:
# No associations found: running the standard logic
# Note: making bzcat first if second
# <p>Read in 743 sources from file seedcheck.zip: <br>selection cut:
#                     (self.df.ts>6)*(self.df.r95<0.6)*(self.df.locqual<8) : 458 remain

# %%
self.all_plots()
# Out:
# wrote list that succeeded to plots/seedcheck/good_seeds.csv
# Saving fig seed_cumulative_ts, ... to plots/seedcheck/seed_cumulative_ts_month10.jpg
# Saving fig locations, ... to plots/seedcheck/locations_month10.jpg
# Saving fig spectral_parameters, ... to plots/seedcheck/spectral_parameters_month10.jpg
# Saving fig localization, ... to plots/seedcheck/localization_month10.jpg
# saved local menu to plots/seedcheck/menu.html
# saved html doc to plots/seedcheck/index.html
# wrote menu /nfs/farm/g/glast/g/catalog/pointlike/skymodels/P301_monthly/month10/plots/index.html

# %%
        for col in 'acat aname adelta_ts aprob adict'.split():
            self.df[col] = self.assoc[col]

# %%
# Out:
# wrote list that succeeded to plots/seedcheck/good_seeds.csv
# Saving fig seed_cumulative_ts, ... to plots/seedcheck/seed_cumulative_ts_month10.jpg
# Saving fig locations, ... to plots/seedcheck/locations_month10.jpg
# Saving fig spectral_parameters, ... to plots/seedcheck/spectral_parameters_month10.jpg
# Saving fig localization, ... to plots/seedcheck/localization_month10.jpg
# saved local menu to plots/seedcheck/menu.html
# saved html doc to plots/seedcheck/index.html
# wrote menu /nfs/farm/g/glast/g/catalog/pointlike/skymodels/P301_monthly/month10/plots/index.html

# %%
self.df[self.df.acat=='bzcat']['aname aprob'.split()].sort_index(by='aname')
# Out:
#                     aname        aprob
# name
# Sh10-1164  5BZBJ0244-5819    0.9647639
# Sh10-1080  5BZBJ0430-2507    0.9006906
# Sh10-121   5BZBJ1057-0059    0.9342598
# Sh10-006   5BZBJ1215+3508    0.9033101
# Sh10-122   5BZBJ1231+6414    0.4259017
# Sh10-019   5BZBJ1238+4431    0.7665401
# Sh10-059   5BZBJ1351+5542  0.003434203
# Sh10-408   5BZBJ1744-0518    0.8143123
# Sh10-1246  5BZGJ0012-1628    0.9869261
# Sh10-062   5BZGJ1059+4343    0.7290763
# Sh10-1158  5BZGJ2239-0631    0.8625382
# Sh10-1256  5BZQJ0014-3059    0.5048248
# Sh10-974   5BZQJ0137+3122     0.978418
# Sh10-1054  5BZQJ0229-7847    0.7511565
# Sh10-1118  5BZQJ0312+0133    0.7497161
# Sh10-994   5BZQJ0406+0637    0.5881467
# Sh10-937   5BZQJ0501-0159    0.9661087
# Sh10-219   5BZQJ0807+5117    0.1069877
# Sh10-229   5BZQJ0819+3226    0.9383769
# Sh10-194   5BZQJ0837+5825    0.2723408
# Sh10-933   5BZQJ0941-8615    0.8632741
# Sh10-262   5BZQJ1037-2934    0.8595226
# Sh10-150   5BZQJ1130-1449    0.1810167
# Sh10-016   5BZQJ1153+3617    0.7840255
# Sh10-000   5BZQJ1224+2122     0.994956
# Sh10-040   5BZQJ1239+0443    0.6934407
# Sh10-185   5BZQJ1246-2547    0.9554269
# Sh10-188   5BZQJ1254-2000   0.05485826
# Sh10-079   5BZQJ1256-0547    0.9976575
# Sh10-060   5BZQJ1311+5513    0.3962568
# Sh10-094   5BZQJ1332-0509    0.9428674
# Sh10-341   5BZQJ1427-4206    0.9910893
# Sh10-333   5BZQJ1554-2704    0.6987841
# Sh10-205   5BZQJ1623+0741    0.3236824
# Sh10-187   5BZQJ1652+6232    0.9369089
# Sh10-239   5BZQJ1756+5748    0.9363142
# Sh10-1004  5BZQJ2036-2830     0.598195
# Sh10-728   5BZQJ2050+3127    0.9747676
# Sh10-1028  5BZQJ2147-7621    0.5190572
# Sh10-1227  5BZQJ2348-1631    0.9328307
# Sh10-178   5BZUJ0849+5108     0.963674
# Sh10-161   5BZUJ1048+7143    0.9478313
# Sh10-399   5BZUJ1626-2951    0.9951917

# %%
ta=self.assoc[self.assoc.aprob>0.8]; #t['aprob acat aname adelta_ts'.split()]

# %%
bznames = np.array(ta.aname[ta.acat=='bzcat'])
bztypes = set([name[3] for name in bznames])
td = dict()       
for t in bztypes:
    td[t]= 0
for n in bznames:
    t = n[3]
    td[t] +=1
pd.DataFrame(td.items(), columns='type count'.split()).to_html(index=False)
# Out:
# u'<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>type</th>\n      <th>count</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td> Q</td>\n      <td> 14</td>\n    </tr>\n    <tr>\n      <td> B</td>\n      <td>  5</td>\n    </tr>\n    <tr>\n      <td> U</td>\n      <td>  3</td>\n    </tr>\n    <tr>\n      <td> G</td>\n      <td>  2</td>\n    </tr>\n  </tbody>\n</table>'

# %%
bztypes, bznames
# Out:
# ({'B', 'G', 'Q', 'U'},
#  array(['5BZQJ1224+2122', '5BZBJ1215+3508', '5BZQJ1256-0547',
#         '5BZQJ1332-0509', '5BZBJ0430-2507', '5BZGJ2239-0631',
#         '5BZBJ0244-5819', '5BZBJ1057-0059', '5BZQJ2348-1631',
#         '5BZGJ0012-1628', '5BZUJ1048+7143', '5BZUJ0849+5108',
#         '5BZQJ1246-2547', '5BZQJ1652+6232', '5BZQJ0819+3226',
#         '5BZQJ1756+5748', '5BZQJ1037-2934', '5BZQJ1427-4206',
#         '5BZUJ1626-2951', '5BZBJ1744-0518', '5BZQJ2050+3127',
#         '5BZQJ0941-8615', '5BZQJ0501-0159', '5BZQJ0137+3122'], dtype=object))

# %%
len(bznames)
# Out:
# 24

# %%
t['bprob'] = [x['prob'][1] if len(x['prob'])>1 else 0 for x in t.adict]
t['bcat'] = [(x['cat'][1] if len(x['prob'])>1 else '') for x in t.adict]

# %%
t['aprob bprob acat bcat'.split()]
# Out:
#                aprob     bprob        acat        bcat
# name
# Sh10-000    0.994956  0.981550       bzcat      crates
# Sh10-006   0.9033101  0.850679       bzcat      crates
# Sh10-023   0.8576047  0.062608      crates         qso
# Sh10-079   0.9976575  0.997658       bzcat       bzcat
# Sh10-094   0.9428674  0.942867       bzcat       bzcat
# Sh10-1048  0.8697462  0.032189      crates  crates_fom
# Sh10-1080  0.9006906  0.630136       bzcat      crates
# Sh10-1129  0.9063166  0.048164      crates  crates_fom
# Sh10-1143  0.9815616  0.365053       bllac         qso
# Sh10-1158  0.8625382  0.058632       bzcat         agn
# Sh10-1164  0.9647639  0.964764       bzcat       bzcat
# Sh10-121   0.9342598  0.086155       bzcat         qso
# Sh10-1227  0.9328307  0.932831       bzcat       bzcat
# Sh10-1246  0.9869261  0.819983       bzcat         agn
# Sh10-161   0.9478313  0.947831       bzcat       bzcat
# Sh10-176    0.934708  0.134825      crates  crates_fom
# Sh10-178    0.963674  0.963674       bzcat       bzcat
# Sh10-185   0.9554269  0.955427       bzcat       bzcat
# Sh10-187   0.9369089  0.889025       bzcat      crates
# Sh10-226   0.8576417  0.070724      crates  crates_fom
# Sh10-229   0.9383769  0.938377       bzcat       bzcat
# Sh10-239   0.9363142  0.851403       bzcat      crates
# Sh10-262   0.8595226  0.859523       bzcat       bzcat
# Sh10-341   0.9910893  0.985941       bzcat      cgrabs
# Sh10-343   0.9694186  0.587639      crates  crates_fom
# Sh10-350   0.9792661  0.979266      crates      crates
# Sh10-396   0.9970811  0.996500         qso      cgrabs
# Sh10-399   0.9951917  0.975063       bzcat         qso
# Sh10-408   0.8143123  0.000000       bzcat
# Sh10-409   0.9329921  0.000000         agn
# Sh10-536   0.9999727  0.636262  pulsar_lat  pulsar_big
# Sh10-728   0.9747676  0.829193       bzcat         qso
# Sh10-749   0.9227778  0.093280      crates  crates_fom
# Sh10-933   0.8632741  0.863274       bzcat       bzcat
# Sh10-937   0.9661087  0.966109       bzcat       bzcat
# Sh10-974    0.978418  0.978418       bzcat       bzcat

# %%
t=pd.DataFrame(self.assoc_sum,columns='catalog count'.split(),).sort_index(by='catalog')
t.index = t.catalog; t.to_html(index=False)
# Out:
# u'<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>catalog</th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>catalog</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>        agn</td>\n      <td>  1</td>\n    </tr>\n    <tr>\n      <td>      bllac</td>\n      <td>  1</td>\n    </tr>\n    <tr>\n      <td>      bzcat</td>\n      <td> 24</td>\n    </tr>\n    <tr>\n      <td>     crates</td>\n      <td>  8</td>\n    </tr>\n    <tr>\n      <td> pulsar_lat</td>\n      <td>  1</td>\n    </tr>\n    <tr>\n      <td>        qso</td>\n      <td>  1</td>\n    </tr>\n  </tbody>\n</table>'

# %%
t.to_html?
