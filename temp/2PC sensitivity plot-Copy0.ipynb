# %% [markdown]
# ## 2PC sensitivity plot

# %%
# %matplotlib inline
import pyfits
os.chdir(os.path.expandvars('$HOME/analysis/pulsars'))

# %%
from uw.like2.pub import healpix_map as hm; reload(hm)
import pyfits
tbl = np.array(pyfits.open(os.path.expandvars('$HOME/skymodels/3years/uw10/Pulsar_limits_fix2.fits'))[1].data,float)
tbl *= 3.25e-12
tbl[np.isinf(tbl)]=0
pl = hm.HParray('pulsar_limits',tbl )
from matplotlib.colors import LogNorm
v = np.array([1,2,5,10,20])*1e-12
ait1=pl.plot(norm=LogNorm(vmin=v[0], vmax=v[-1]))
cb = ait1.colorbar
cb.set_ticks(v)
cb.set_ticklabels(['%d' %x for x in v/v[0]])
cb.set_label(r'$\mathrm{Energy\ flux\ [10^{-12} erg \ s^{-1} cm^{-2}]}$')

# %% [markdown]
# But the final figure was smoothed -- try to do that here

# %%
reload(hm)
s = hm.HPGaussSmooth(pl, 1.0, 64)

# %%
# %time col= s.getcol()
# Out:
# CPU times: user 15min 54s, sys: 466 ms, total: 15min 55s
# Wall time: 15min 54s

# %%
s16 = hm.HPGaussSmooth(pl, 1.0, 16)
# %time col16 = s16.getcol()
hm.HParray('col16', col16).plot(norm=LogNorm(vmin=v[0], vmax=v[-1]))
# Out:
# CPU times: user 59.7 s, sys: 31 ms, total: 59.7 s
# Wall time: 59.6 s

# %%
s1 = hm.HPGaussSmooth(pl, 1.0, 4)
# %time col1 = s1.getcol()
hm.HParray('col1', col1).plot()#norm=LogNorm(vmin=v[0], vmax=v[-1]));
# Out:
# CPU times: user 4.07 s, sys: 7 ms, total: 4.08 s
# Wall time: 4.06 s

# %%
hm.HParray('index4', np.arange(12*4**2)).plot();

# %%
# test the _call_ code
from pointlike import IntVector
from skymaps import SkyDir
self=s1
s1.nside, len(s1.vec), 
skydir = SkyDir(0,0, SkyDir.GALACTIC) #s1._dirfun(0)
dir0, s1._indexfun(skydir)
iv = IntVector()
self.hp.query_disc(skydir, 3*self.sigma, iv)
sds = map(self._dirfun, iv)
deltas = np.array(map(skydir.difference, sds),np.float32)
values = np.array(self.vec[list(iv)],np.float32)
notnan = ~np.isnan(values)
weights = np.array(map( lambda x: np.exp(-0.5*(x/self.sigma)**2), deltas[notnan]), np.float32)
ret =np.dot(values[notnan],weights) / sum(weights)
ret,min(values),max(values), self.vec[self._indexfun(skydir)] #zip(deltas, weights, values)
# Out:
# (2.3351359123389961e-11, 3.5954607e-12, 4.8864923e-11, 1.973032259941101e-11)

# %% [markdown]
# Try a scan along l=0

# %%
sdirs = [SkyDir(0, b, SkyDir.GALACTIC) for b in np.linspace(-90,91,5)]; sdirs
# Out:
# [SkyDir(12.859,-27.128),
#  SkyDir(319.941,-41.654),
#  SkyDir(265.918,-28.675),
#  SkyDir(228.712,-0.630),
#  SkyDir(191.912,27.669)]

# %%
# %time t0.plot(norm=LogNorm(vmin=v[0], vmax=v[-1]))
# Out:
# CPU times: user 5.06 s, sys: 7 ms, total: 5.07 s
# Wall time: 5.06 s

# %%
t = hm.HPGaussSmooth(pl, 1.0, 256)

# %%
imax = 12*256**2-1
dmax = t.dirfun(imax); dmax
# %time t[imax], t(dmax), t0(dmax)
# Out:
# CPU times: user 44 ms, sys: 0 ns, total: 44 ms
# Wall time: 37.3 ms
# (2.6303641051054e-12, 2.4216883186491389e-12, 1.799105703830719e-12)

# %%
# %time t.plot(norm=LogNorm(vmin=v[0], vmax=v[-1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-6914fe59911b> in <module>()
# ----> 1 get_ipython().magic(u'time t.plot()#norm=LogNorm(vmin=v[0], vmax=v[-1]))')
#
# /phys/users/tburnett/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2203         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2204         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2205         return self.run_line_magic(magic_name, magic_arg_s)
#    2206
#    2207     #-------------------------------------------------------------------------
#
# /phys/users/tburnett/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2124                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2125             with self.builtin_trap:
# ...

# %%
reload(hm)
t64 = hm.HPGaussSmooth(pl, 1.0, 64)
# %time z64 = t64.getcol()
g64 = hm.HParray('gauss64', z64)
g64.plot(norm=LogNorm(vmin=v[0], vmax=v[-1]))
# Out:
# CPU times: user 16min 6s, sys: 357 ms, total: 16min 6s
# Wall time: 16min 6s

# %%
t128 = hm.HPGaussSmooth(pl, 1.0, 128)
# %time z128 = t128.getcol()
g128 = hm.HParray('gauss128', z128)
g128.plot(norm=LogNorm(vmin=v[0], vmax=v[-1]))
# Out:
# CPU times: user 1.53 s, sys: 19 ms, total: 1.55 s
# Wall time: 1.53 s

# %%
z2 = hm.HEALPixFITS([t])
# Out:
# appended column pulsar_limits

# %%
z2.write('smoothed_pulsar_limit.fits')
# Out:
# wrote FITS file to smoothed_pulsar_limit.fits

# %% [markdown]
# Try the full resolution, get the smoothed value for every pixel (should take a long time)

# %%
reload(hm)
t9 = hm.HPGaussSmooth(pl, 1.0)
# %time zz = t9.getcol()
# Out:
# CPU times: user 2.11 s, sys: 66 ms, total: 2.18 s
# Wall time: 2.13 s

# %%
# %time t9[0]
# Out:
# CPU times: user 1 ms, sys: 0 ns, total: 1 ms
# Wall time: 40.1 ms
# 2.720053419470787e-12

# %%
zz[0]
# Out:
# 2.7200533e-12
