# %% [markdown]
# #GC analysis for pass 8, uw909

# %%
# %matplotlib inline
os.chdir(os.path.expandvars('$FERMI/skymodels/P301_5years/uw909'))
from uw.like2 import  main; reload(main)
from skymaps import SkyDir

# %%
r = main.ROI('.', 235)
# Out:
# FT file(s) "/afs/slac/g/glast/groups/catalog//pointlike/fermi/data/../../P8_P301/Source/P301_*.fits" not found: assume None to test for valid binfile
# 77 total sources: 0 extended, 3 global

# %%
sn ='P7R42735'
s = r.sources.find_source(sn);
tsp= r.plot_tsmap(sn, galactic=True, tsplot=True);
sgraloc=SkyDir(359.9442,-0.0462, SkyDir.GALACTIC)
dts = tsp.plot(loc=sgraloc, label='Sgr A*', color='white')
p3fgl= SkyDir(266.4195 , -29.003)
dts3 = tsp.plot(loc=p3fgl, label='3FGL', color='white', symbol='x')
print 'delta TS for Sgr A*, 3FGL: %.1f, %.1f' % (dts, dts3)
# Out:
# TSplot: filling 225 pixels...
# delta TS for Sgr A*, 3FGL: -19.2, -35.1

# %% [markdown]
# Adjust the ellipse parameters with systematics

# %%
t = np.array(s.ellipse[2:4])*3600; u = 0.005*3600/2.45; f=1.07
t, u, np.sqrt((t*f)**2+(u**2))
# Out:
# (array([ 10.42727426,   9.58141519]),
#  7.346938775510203,
#  array([ 13.35890161,  12.61282506]))

# %% [markdown]
# Check actual distance to Sgr A*

# %%
loc = SkyDir(*s.ellipse[:2])
d =np.degrees(loc.difference(sgraloc))*3600
print 'Distance: %.1f arcsec' % d
# Out:
# Distance: 42.7 arcsec

# %%
r.plot_sed();

# %%
#r.localize(  update=True);
# Out:
# Localizing source P7R42735, tolerance=1.0e-04...
# 	     moved     delta        ra       dec         a         b      qual
# 	    0.0000    0.0000  266.4163  -29.0081
# 	    0.0097    0.0097  266.4052  -29.0089    0.0002    0.0002   17.6104
# 	    0.0018    0.0116  266.4031  -29.0092    0.0025    0.0023    4.6647
# 	    0.0002    0.0118  266.4029  -29.0092    0.0029    0.0027    0.1150
# 	    0.0000    0.0119  266.4028  -29.0092    0.0029    0.0027    0.0150
# TS change: 19.41

# %%
tsp= r.plot_tsmap(sn, galactic=True, tsplot=True);
dts = tsp.plot(loc=sgraloc, label='Sgr A*', color='white')
p3fgl= SkyDir(266.4163 , -29.0081)
dts3 = tsp.plot(loc=p3fgl, label='3FGL', color='white')
print 'delta TS for Sgr A*, 3FGL: %.1f, %.1f' % (dts, dts3)
# Out:
# setting size from 1659059882.61 to 2.0
# TSplot: filling 225 pixels...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /afs/slac/g/glast/groups/catalog/pointlike/python/uw/utilities/image.pyc in pyskyfun(v)
#     621         if skyfun.__class__.__name__ !='PySkyFunction':
#     622             def pyskyfun(v):
# --> 623                 return skyfun(SkyDir(Hep3Vector(v[0],v[1],v[2])))
#     624             self.skyimage.fill(PySkyFunction(pyskyfun))
#     625         else:
#
# /afs/slac/g/glast/groups/catalog/pointlike/python/uw/like2/localization.pyc in TSmap(self, skydir)
#      56             2x the log(likelihood ratio) from the nominal position
#      57         """
# ---> 58         val= 2*(self.log_like(skydir)-self.maxlike)
#      59         return val
#      60
#
# /afs/slac/g/glast/groups/catalog/pointlike/python/uw/like2/localization.pyc in log_like(self, skydir)
# ...

# %%
r.localize(  update=True);
# Out:
# Localizing source P7R42735, tolerance=1.0e-04...
# 	     moved     delta        ra       dec         a         b      qual
# 	    0.0000    0.0000   90.8094  -57.8510
# 	    0.1549    0.1549   90.7531  -57.6991275318416.4103275318416.4103   17.7022
# trying a recenter...
# 	   77.6062   77.4537  242.5412  -41.9381110603992.1740110179893.9214   17.6763
# 	 -attempt to move beyond maxdist=1.0
# TS change: 0.00
