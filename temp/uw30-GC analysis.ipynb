# %% [markdown]
# #GC analysis for pass 7, uw30

# %%
# %matplotlib inline
os.chdir(os.path.expandvars('$FERMI/skymodels/P202/uw30'))
from uw.like2 import  main; reload(main)
from skymaps import SkyDir

# %%
r = main.ROI('.', 888)
# Out:
# FT file(s) "/afs/slac/g/glast/groups/catalog//pointlike/fermi/data/../../P7_P202/Source/*.fits" not found: assume None to test for valid binfile
# FT file(s) "/afs/slac/g/glast/groups/catalog//pointlike/fermi/data/../../P7_P202/ft2_4years.fits" not found: assume None to test for valid binfile
# 142 total sources: 3 extended, 4 global
# /afs/slac/g/glast/groups/catalog/python/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
sn ='P7R42735'
s = r.sources.find_source(sn);
tsp= r.plot_tsmap(sn, galactic=True, tsplot=True);
sgraloc=SkyDir(359.9442,-0.0462, SkyDir.GALACTIC)
dts = tsp.plot(loc=sgraloc, label='Sgr A*', color='white')
print 'delta TS for Sgr A*: %.1f' % dts
# Out:
# TSplot: filling 224 pixels...
# delta TS for Sgr A*: -3.4

# %% [markdown]
# Adjust the ellipse parameters with systematics

# %%
t = np.array(s.ellipse[2:4])*3600; u = 0.005*3600/2.45; f=1.07
t, u, np.sqrt((t*f)**2+(u**2))
# Out:
# (array([ 10.42727426,   9.58141519]),
#  7.346938775510203,
#  array([ 13.35890161,  12.61282506]))

# %% [markdown]
# Check actual distance to Sgr A*

# %%
loc = SkyDir(*s.ellipse[:2])
d =np.degrees(loc.difference(sgraloc))*3600
print 'Distance: %.1f arcsec' % d
# Out:
# Distance: 42.7 arcsec

# %%
r.plot_sed();

# %%
r.localize(  update=True);
# Out:
# Localizing source P7R42735, tolerance=1.0e-04...
# 	     moved     delta        ra       dec         a         b      qual
# 	    0.0000    0.0000  266.4163  -29.0081
# 	    0.0127    0.0127  266.4144  -28.9956    0.0005    0.0004   17.4176
# 	    0.0020    0.0120  266.4124  -28.9966    0.0040    0.0040    2.6719
# 	    0.0002    0.0121  266.4122  -28.9966    0.0043    0.0043    0.0887
# 	    0.0000    0.0121  266.4121  -28.9966    0.0044    0.0043    0.0243
# TS change: 7.77

# %%
tsp= r.plot_tsmap(sn, galactic=True, tsplot=True);
dts = tsp.plot(loc=sgraloc, label='Sgr A*', color='white')
print 'delta TS for Sgr A*: %.1f' % dts
# Out:
# TSplot: filling 225 pixels...
# delta TS for Sgr A*: 0.0

# %%
r.localize(  update=True);
# Out:
# Localizing source P7R42735, tolerance=1.0e-04...
# 	     moved     delta        ra       dec         a         b      qual
# 	    0.0000    0.0000  266.4028  -29.0092
# 	    0.0018    0.0018  266.4008  -29.0092    0.0002    0.0002   17.5600
# 	    0.0016    0.0002  266.4026  -29.0092    0.0025    0.0023    4.4767
# 	    0.0002    0.0000  266.4028  -29.0092    0.0029    0.0027    0.1061
# 	    0.0000    0.0000  266.4028  -29.0092    0.0029    0.0027    0.0205
# TS change: 0.00
