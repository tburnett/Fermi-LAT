# %% [markdown]
# # Analyze counts
# Develop the "counts.CountPlots" analysis class

# %%
# %matplotlib inline
#os.chdir(os.path.expandvars('$FERMI/skymodels/P301_6years/uw972'))
os.chdir(os.path.expandvars('$FERMI/skymodels/P301_monthly/month18'))
from uw.like2.analyze import (sourceinfo, residuals, background, environment, 
                              associations, counts,analysis_base, localization,  roi_info,); 
map(reload, (sourceinfo, counts, residuals,background, environment,associations,roi_info,localization));

# %%
self = counts.CountPlots()
# Out:
# unpacking file /nfs/farm/g/glast/g/catalog/pointlike/skymodels/P301_monthly/month18/pickle.zip ... found 1728 *.pickle files in folder pickle
# Extracting history info from the ROI analysises

# %%
def loglikelihood(self):
    """log likelihood

    Progression of the log likelihood for the processing stages
    """
    fig, ax = plt.subplots(1,1, figsize=(8,4))
    ds=self.sinfo.delta_sum
    x = range(len(self.sinfo))
    ax.plot( x, np.cumsum(ds), 'o--');
    ax.set_xticks(x)
    ax.set_xticklabels(list(self.sinfo.stage), rotation=45, va='top', ha='right')
    plt.setp(ax, xlim=(x[0]-0.5, x[-1]+0.5), 
             title='change in total log likelihood', xlabel='processing stage', ylabel='log likelihood')
    ax.grid(True, alpha=0.5)
    axr = ax.twinx()
    plt.setp(axr, ylabel='changed ROIs', ylim=(0,self.sinfo.gt10.max()+5) )
    axr.plot( x, self.sinfo.gt10, 'Dr--')
    return fig

loglikelihood(self);

# %%
self.all_plots()
# Out:
# Saving fig loglikelihood, ... to plots/counts/loglikelihood_month18.jpg
# Saving fig chisq_plots, ... to plots/counts/chisq_plots_month18.jpg
# Saving fig residual_maps, ... to plots/counts/residual_maps_month18.jpg
# Saving fig residual_plot, ... to plots/counts/residual_plot_month18.jpg
# Saving fig residual_hists, ... to plots/counts/residual_hists_month18.jpg
# Saving fig ridge_spectral_residuals, ... to plots/counts/ridge_spectral_residuals_month18.jpg
# saved local menu to plots/counts/menu.html
# saved html doc to plots/counts/index.html
# wrote menu /nfs/farm/g/glast/g/catalog/pointlike/skymodels/P301_monthly/month18/plots/index.html

# %%
s=hd[516]
delta=np.array([x['delta'] for x in s.values()] )
logl =np.array([x['logl'] for x in s.values()] )
logl[:5], delta[:5]
# Out:
# (array([ 125336.80443834,  126403.17630229,  181266.69124995,
#          127738.52637476,  118864.16571706]),
#  array([ 0.14163945,  0.07624753,  0.07231568,  0.05075173, -1.33325931]))

# %%
s=hd[515]
delta=np.array([x['delta'] for x in s.values()] )
logl =np.array([x['logl'] for x in s.values()] )
logl[:5], delta[:5]
# Out:
# (array([ 125336.79410984,  126403.22692142,  181266.72924748,
#          127738.4732186 ,  118864.18421206]),
#  array([ 0.16414139,  0.17167298,  0.18879196, -0.03422549, -1.34355302]))

# %%
sorted(hd.keys())
# Out:
# [0,
#  1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  78,
#  79,
#  80,
#  81,
#  82,
#  83,
#  84,
#  107,
#  108,
#  113,
#  123,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  139,
#  140,
#  141,
#  142,
#  143,
#  146,
#  147,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  164,
#  165,
#  166,
#  167,
#  169,
#  171,
#  172,
#  173,
#  175,
#  176,
#  177,
#  178,
#  179,
#  180,
#  183,
#  184,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  220,
#  221,
#  222,
#  223,
#  224,
#  225,
#  226,
#  227,
#  229,
#  230,
#  231,
#  232,
#  233,
#  234,
#  235,
#  236,
#  237,
#  238,
#  239,
#  240,
#  241,
#  242,
#  243,
#  244,
#  245,
#  246,
#  247,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
# ...

# %%
self.skymodel
# Out:
# 'month18'
