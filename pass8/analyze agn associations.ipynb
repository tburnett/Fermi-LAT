# %% [markdown]
# #Analyze AGN associations

# %%
# %matplotlib inline
os.chdir(os.path.expandvars('$FERMI/skymodels/P301_6years/uw972'))
from uw.like2.analyze import (sourceinfo, associations, ); 
map(reload, (sourceinfo, associations,));

# %%
self = associations.Associations()
# Out:
# loading sources.pickle
# using associations found in sourceinfo
# associated: 2281/6952

# %%
self.bzcat_study();
# Out:
# agns: 1669
# [446, 993, 219, 11, 0]
# Writing bzcat summary to plots/associations/bzcat_summary.csv

# %%
self.all_plots();
# Out:
# /afs/slac/g/glast/groups/catalog/python/anaconda/lib/python2.7/site-packages/pyfits/column.py:1040: VerifyWarning: Invalid keyword for column 1: Column start option (TBCOLn) is not allowed for binary table columns (got 10).  The invalid keyword will be ignored for the purpose of formatting the data in this column.
#   VerifyWarning)
# /afs/slac/g/glast/groups/catalog/python/anaconda/lib/python2.7/site-packages/pyfits/column.py:1040: VerifyWarning: Invalid keyword for column 2: Column start option (TBCOLn) is not allowed for binary table columns (got 21).  The invalid keyword will be ignored for the purpose of formatting the data in this column.
#   VerifyWarning)
# /afs/slac/g/glast/groups/catalog/python/anaconda/lib/python2.7/site-packages/pyfits/column.py:1040: VerifyWarning: Invalid keyword for column 3: Column start option (TBCOLn) is not allowed for binary table columns (got 28).  The invalid keyword will be ignored for the purpose of formatting the data in this column.
#   VerifyWarning)
# /afs/slac/g/glast/groups/catalog/python/anaconda/lib/python2.7/site-packages/pyfits/column.py:1040: VerifyWarning: Invalid keyword for column 4: Column start option (TBCOLn) is not allowed for binary table columns (got 35).  The invalid keyword will be ignored for the purpose of formatting the data in this column.
#   VerifyWarning)
# /afs/slac/g/glast/groups/catalog/python/anaconda/lib/python2.7/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# CAT-VERSION= '1.36' / Catalogue version
#   self._image)
# opening LAT catalog file /afs/slac/g/glast/groups/catalog//pointlike/fermi/catalog/srcid/cat/obj-pulsar-lat_v867.fits
# sources with exp cutoff not in LAT catalog: []
# Catalog entries not found: ['PSR J1623-5005', 'PSR J1410-6132', 'PSR J1028-5819', 'PSR J0633+1746', 'PSR J1744-7619', 'PSR J1513-5908', 'PSR J1730-3350', 'PSR J1831-0952', 'PSR J0737-3039A']
# 39 sources found in BigFile pulsar catalog
# Saving fig association_vs_ts, ... to plots/associations/association_vs_ts_uw972.jpg
# AGN: localization factor=1.07
# LAT pulsars: localization factor=1.18
# other ids: localization factor=1.10
# Saving fig localization_check, ... to plots/associations/localization_check_uw972.jpg
# agns: 1669
# [446, 993, 219, 11, 0]
# Writing bzcat summary to plots/associations/bzcat_summary.csv
# Saving fig bzcat_study, ... to plots/associations/bzcat_study_uw972.jpg
# saved local menu to plots/associations/menu.html
# saved html doc to plots/associations/index.html
# wrote menu /nfs/farm/g/glast/g/catalog/pointlike/skymodels/P301_6years/uw972/plots/index.html
