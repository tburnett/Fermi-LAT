# %% [markdown]
# # KDE plots
# Make the basic KDE
# [Kernel Density Estimator](https://en.wikipedia.org/wiki/Kernel_density_estimation) plots available.
#
# This map includes all (front,back) photons above 500 (1000) GeV, for the first 6 years of FERMI skysurvey data, excluding a few bright GRBs and solar flares. The kernel is the PSF corresponding to the energy and conversion type.

# %%
from IPython import display
os.chdir('/nfs/farm/g/glast/g/catalog/pointlike/skymodels/P301_6years/uw972')
display.Image('plots/hptables_ts/kde_map_uw972.jpg')

# %%
The corresponding FITS file is named hptables_ts_kde_512.fits in this folder
