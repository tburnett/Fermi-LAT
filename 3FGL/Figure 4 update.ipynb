# %% [markdown]
# #Update Figure 4 in the 3FGL paper
# Need to clean up a bit
#
# It is created by analyze.sourceinfo.SourceInfo.fit_quality, from the data at $FERMI/skymodels/P202/uw30
# and saved to
# /nfs/farm/g/glast/u55/burnett/lat3fgl/figs
#
# [comment page on version 2](https://confluence.slac.stanford.edu/display/SCIGRPS/Comments+on+3FGL+Catalog+Paper+v2)

# %%
# %matplotlib inline
os.chdir(os.path.expandvars('$FERMI/skymodels/P202/uw30'))
from uw.like2.analyze import (sourceinfo,); reload( sourceinfo)
# Out:
# <module 'uw.like2.analyze.sourceinfo' from '/afs/slac/g/glast/groups/catalog/pointlike/python/uw/like2/analyze/sourceinfo.py'>

# %%
self=sourceinfo.SourceInfo()
# Out:
# loading sources.pickle

# %%
fig =self.fit_quality(grid_flag=False, legend_flag=False);
# Out:
# 0 sources with bad fits
# fit quality averages: powerlaw: 11.2, logparabola: 10.1, expcutoff(hilat): 8.2, expcutoff(lolat): 26.7
# **File sedfig/P7R42139_sed*.jpg not found
# **File sedfig/P7R41775_sed*.jpg not found
# **File sedfig/P7R41230_sed*.jpg not found
# **File sedfig/P7R42655_sed*.jpg not found
# **File sedfig/P7R42670_sed*.jpg not found
# **File sedfig/P7R42673_sed*.jpg not found
# **File sedfig/P7R42681P_sed*.jpg not found
# **File sedfig/P7R43239_sed*.jpg not found
# **File sedfig/P7R43223P_sed*.jpg not found
# **File sedfig/P7R43304_sed*.jpg not found
# **File sedfig/PSR_J2229p6114_sed*.jpg not found
# **File sedfig/PSR_J0205p6449_sed*.jpg not found
# **File sedfig/P7R40397_sed*.jpg not found
# **File sedfig/PSR_J0633p1746_sed*.jpg not found
# **File sedfig/P7R41235AG_sed*.jpg not found
# **File sedfig/P7R41296_sed*.jpg not found
# **File sedfig/PSR_J1124-5916_sed*.jpg not found
# **File sedfig/P7R42095_sed*.jpg not found
# **File sedfig/P7R42307_sed*.jpg not found
# ...

# %%
figpath='/nfs/farm/g/glast/u55/burnett/lat3fgl/figs/fit_quality'
for ext in ('.eps', '.png'):
    fig.savefig(figpath+ext)
