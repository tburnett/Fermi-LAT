# %% [markdown]
# #Update Figure 2 in the 3FGL paper
# Need to clean up a bit
#
# It is created by analyze.counts.CountPlots.chisq_plots, from the data at $FERMI/skymodels/P202/uw30
# and saved to
# /nfs/farm/g/glast/u55/burnett/lat3fgl/figs
#
# [comment page on version 2](https://confluence.slac.stanford.edu/display/SCIGRPS/Comments+on+3FGL+Catalog+Paper+v2)

# %%
# %matplotlib inline
os.chdir(os.path.expandvars('$FERMI/skymodels/P202/uw29'))
from uw.like2.analyze import (counts,); reload( counts)
# Out:
# <module 'uw.like2.analyze.counts' from '/afs/slac/g/glast/groups/catalog/pointlike/python/uw/like2/analyze/counts.py'>

# %%
self=counts.CountPlots()
# Out:
# unpacking file /nfs/farm/g/glast/u55/catalog/pointlike/skymodels/P202/uw29/pickle.zip ... found 1728 *.pickle files in folder pickle

# %%
fig =self.chisq_plots(unweight=False, grid_flag=False)
ax = fig.get_axes()[1]
plt.setp(ax,xlabel='Galactic Longitude', ylabel='sin(Galactic Latitude)')

# %%
figpath='/nfs/farm/g/glast/u55/burnett/lat3fgl/figs/chisq_plot'
for ext in ('.eps', '.png'):
    fig.savefig(figpath+ext)
